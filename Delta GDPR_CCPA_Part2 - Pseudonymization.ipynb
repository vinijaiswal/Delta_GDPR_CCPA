# %% [markdown]
# ##5B. Pseudonymization
# <img src="https://miro.medium.com/max/1400/1*RYp7KmHt8OE5LrcIKX9PBQ.png" width=400/>

# %%
# %sh pip install faker
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">Collecting faker
# ...
# You are using pip version 19.0.3, however version 20.2b1 is available.
# You should consider upgrading via the &#39;pip install --upgrade pip&#39; command.
# </div>

# %%
# %python
####FUNCTIONS
import pandas as pd
from faker import Factory
import pandas as pd
import random

from faker import Faker
fake = Faker()

###VARIABLE DEFINITIONS
c_current_cdemo_sk = ["c1", "c2", "c3", "c4", "c5"]
c_current_hdemo_sk = ["h1", "h2", "h3", "h4", "h5"]
salutations = ["Mr.", "Mrs.", "Ms", "Dr", "Prof", "None"]
print("c_customer_id : ", fake.uuid4())
print("c_customer_sk : ", fake.sha256())
print("c_current_cdemo_sk : ", fake.words(1, c_current_cdemo_sk, True))
print("c_current_hdemo_sk : ", fake.words(1, c_current_hdemo_sk, True))
print("c_current_addr_sk : ", fake.address())
print("c_first_shipto_date_sk", fake.date())
print("c_first_sales_date_sk", fake.date())
print("c_salutation : ", fake.words(1, salutations, True)[0])
print("c_first_name : ", fake.first_name())
print("c_last_name : ", fake.last_name())
print("c_preferred_cust_flag : ", fake.words(1, ["Y", "N"], True)[0])
print("c_birth_year : ", fake.year())
print("c_birth_country : ", fake.words(1, ["AB", "BC", "CD"], True)[0])
print("c_email_address : ", fake.email())
print("c_last_review_date : ", fake.date())


df1 = pd.DataFrame(columns=("c_customer_id", "c_customer_sk", "c_current_cdemo_sk", "c_current_hdemo_sk", "c_first_shipto_date_sk", "c_first_sales_date_sk", "c_first_name", "c_last_name", "c_preferred_cust_flag", "c_email_address", "c_last_review_date"))

for i in range(100):
  userRecord = [fake.uuid4(), \
                fake.sha256(), \
                fake.words(1, c_current_cdemo_sk, True)[0], \
                fake.words(1, c_current_hdemo_sk, True)[0], \
                fake.date(), \
                fake.date(), \
                fake.first_name(), \
                fake.last_name(), \
                fake.words(1, ["Y", "N"], True)[0], \
                fake.email(), \
                fake.date()] 
  df1.loc[i] = [item for item in userRecord]
  
  
customer_data = spark.createDataFrame(df1)
display(customer_data)
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# ...

# %% [markdown]
# #####Pseudonymize identifiable info in original table by using Hash

# %%
# %python
import pyspark.sql.functions as f
###Psedonymize identifiable info in original table
customer_data = customer_data.withColumn("c_email_address_pseudonym", f.sha2(customer_data['c_email_address'], 256))
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
# %sql
DROP table gdpr.customer_lookup;
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr></tr></thead><tbody></tbody></table></div>

# %%
# %python
cust_lookup = customer_data.select("c_email_address_pseudonym", "c_email_address", "c_first_name", "c_last_name")

cust_lookup.write.mode("overwrite").format("delta").saveAsTable("gdpr.customer_lookup")
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
# %sql
DROP table gdpr.customer_pseudo;
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr></tr></thead><tbody></tbody></table></div>

# %%
# %python
##drop the identifiable columns from the original table
customer_data.drop("c_email_address").drop("c_first_name").drop("c_last_name").write.mode("overwrite").format("delta").saveAsTable("gdpr.customer_pseudo")
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %% [markdown]
# Let's check both tables now!

# %%
# %sql
select * from gdpr.customer_pseudo
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# ...

# %%
# %sql
select * from gdpr.customer_lookup
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# ...

# %% [markdown]
# ####Let's say you get a delete request

# %%
# %sql
select * from gdpr.customer_lookup where c_email_address =  "nsmith@gmail.com"
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>c_email_address_pseudonym</th><th>c_email_address</th><th>c_first_name</th><th>c_last_name</th></tr></thead><tbody><tr><td>c08e49aa90f1d56074ab47d20117266d35b960b9d8153fed261464a5724f8a60</td><td>nsmith@gmail.com</td><td>Robert</td><td>Johnson</td></tr></tbody></table></div>

# %%
# %sql
DELETE FROM gdpr.customer_lookup WHERE c_email_address =  "nsmith@gmail.com";
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr></tr></thead><tbody></tbody></table></div>

# %%
# %sql
select * from gdpr.customer_pseudo where c_email_address_pseudonym =  "c08e49aa90f1d56074ab47d20117266d35b960b9d8153fed261464a5724f8a60"
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>c_customer_id</th><th>c_customer_sk</th><th>c_current_cdemo_sk</th><th>c_current_hdemo_sk</th><th>c_first_shipto_date_sk</th><th>c_first_sales_date_sk</th><th>c_preferred_cust_flag</th><th>c_last_review_date</th><th>c_email_address_pseudonym</th></tr></thead><tbody><tr><td>bb80c5c0-ad2b-4065-8173-555ca79fa323</td><td>751799b1b3a6ae90053deb2ee0b712f560500ceef45778a18cb97ea255f7ae31</td><td>c4</td><td>h1</td><td>1984-09-23</td><td>1992-04-07</td><td>N</td><td>2002-02-18</td><td>c08e49aa90f1d56074ab47d20117266d35b960b9d8153fed261464a5724f8a60</td></tr></tbody></table></div>

# %%
# %sql
DELETE from gdpr.customer_pseudo where c_email_address_pseudonym =  "c08e49aa90f1d56074ab47d20117266d35b960b9d8153fed261464a5724f8a60"
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr></tr></thead><tbody></tbody></table></div>
